# %% [markdown]
# ###Importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Importing dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset = pd.read_csv('./drive/MyDrive/Colab Notebooks/a1_CompanyReviews_HistoricDump.csv', delimiter = ',', quoting = 3, encoding='utf-8')

# %%
dataset.shape
# Out:
# (208, 2)

# %%
dataset.head()
# Out:
#                                               Review  Liked
# 0  Excellent product. Pretty competitive with pri...      1
# 1                                A+++ great products      1
# 2                    snelle levering. prima product.      1
# 3  I ordered a Phone Cover and it was delivered t...      1
# 4                                       Good bargain      1

# %% [markdown]
# ### Data cleaning

# %%
import re
import nltk

nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

all_stopwords = stopwords.words('english')
all_stopwords.remove('not')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus=[]

for i in range(0, 208):
  review = re.sub('[^a-zA-Z]', ' ', dataset['Review'][i])
  review = review.lower()
  review = review.split()
  review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
  review = ' '.join(review)
  corpus.append(review)

# %%
corpus
# Out:
# ['excel product pretti competit price howev not cheapest',
#  'great product',
#  'snell lever prima product',
#  'order phone cover deliv next morn get better servic well done thank',
#  'good bargain',
#  'got first order last week enjoy leg super comfi fit great new favorit pant workout',
#  'go programm',
#  'abl fill posit great time manner highli qualifi candid',
#  'thank love sheepskin boot',
#  'handi problem easi return would highli recommend',
#  'easi better valu bigger name hassl free',
#  'super fast deliveri easi payment item descript accur thank',
# ...

# %% [markdown]
# ### Data transformation

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1420)

# %%
X = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:, -1].values

# %%
# Saving BoW dictionary to later use in prediction
import pickle
bow_path = './drive/MyDrive/Colab Notebooks/c1_BoW_Sentiment_Model.pkl'
pickle.dump(cv, open(bow_path, "wb"))

# %% [markdown]
# ### Dividing dataset into training and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %% [markdown]
# ### Model fitting (Naive Bayes)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
# Exporting NB Classifier to later use in prediction
import joblib
joblib.dump(classifier, './drive/MyDrive/Colab Notebooks/c2_Classifier_Sentiment_Model')
# Out:
# ['./drive/MyDrive/Colab Notebooks/c2_Classifier_Sentiment_Model']

# %% [markdown]
# ###Model performance

# %%
y_pred = classifier.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)

accuracy_score(y_test, y_pred)
# Out:
# [[15  6]
#  [ 9 12]]
# 0.6428571428571429
